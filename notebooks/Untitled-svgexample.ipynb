# %%
# %load_ext rpy2.ipython
## Cool! R-plot to svg devices but requires apt-get install libcairo2-dev and Cairo R package:
# %Rdevice svg
# %R load('Untitled5.RData')
# %R print(ls())
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
#  [1] "B.ea1"     "B.ea1a"    "B.ea2"     "B.ed1"     "B.ed2"     "B.gr1"
#  [7] "B.gr2"     "B.temp1"   "B.temp2"   "genes"     "good_gene" "gr"
# [13] "imp_vars"  "info"      "my.util"   "x"         "x.orig"    "xx"
# [19] "Y"

# %%
# %R Y <- info$electron.donor
# %R imp_vars = names(B.ed1$finalDecision[B.ed1$finalDecision=='Confirmed'])
# %Rpull imp_vars
# %R xx=cbind(x[,Y=='lactate'],x[,Y=='pyruvate'],x[,Y=='hydrogen']); matplot(t(xx[imp_vars,,drop=F]),typ='l')
